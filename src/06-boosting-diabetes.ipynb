# %% [markdown]
# # Proyecto Boosting

# %% [markdown]
# En este proyecto vamos a crear un algoritmo supervisado **Boosting** con los datos del proyecto anterior *04_decision_tree_diabetes* y *05_random_forest_diabetes*
